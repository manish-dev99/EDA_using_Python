# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('flights_data.csv')
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB
# (300153, 12)

# %%
df.isnull().sum()
# Out:
# index               0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
night_flights = df[df['departure_time'] == 'Night']


display(night_flights.head())
# Out:
#     index    airline  flight source_city departure_time stops arrival_time  \
# 40     40  Air_India  AI-504       Delhi          Night   one      Morning
# 44     44  Air_India  AI-479       Delhi          Night   one    Afternoon
# 50     50  Air_India  AI-540       Delhi          Night   one      Morning
# 58     58     Indigo  6E-369       Delhi          Night   one      Morning
# 69     69    Vistara  UK-871       Delhi          Night   one    Afternoon
#
#    destination_city    class  duration  days_left  price
# 40           Mumbai  Economy     11.00          1  12150
# 44           Mumbai  Economy     17.75          1  12215
# 50           Mumbai  Economy     11.42          1  12990
# 58           Mumbai  Economy     10.42          1  13279
# 69           Mumbai  Economy     17.92          1  14408

# %%
df['arrival_time'].value_counts().idxmax()
# Out:
# 'Night'

# %%
df['departure_time'].value_counts().idxmax()
# Out:
# 'Morning'

# %%
df['class'].value_counts()
# Out:
# class
# Economy     206666
# Business     93487
# Name: count, dtype: int64

# %%
df['destination_city'].value_counts()
# Out:
# destination_city
# Mumbai       59097
# Delhi        57360
# Bangalore    51068
# Kolkata      49534
# Hyderabad    42726
# Chennai      40368
# Name: count, dtype: int64

# %%
a = df[(df['destination_city'] == 'Bangalore') & (df['departure_time'] == 'Night')]
display(a)
# Out:
#          index    airline   flight source_city departure_time stops  \
# 9997      9997  Air_India   AI-504       Delhi          Night  zero
# 10031    10031    Vistara   UK-953       Delhi          Night   one
# 10033    10033    Vistara   UK-953       Delhi          Night   one
# 10038    10038     Indigo  6E-2147       Delhi          Night   one
# 10041    10041    Vistara   UK-953       Delhi          Night   one
# ...        ...        ...      ...         ...            ...   ...
# 295908  295908    Vistara   UK-838     Chennai          Night   one
# 295909  295909    Vistara   UK-838     Chennai          Night   one
# 295915  295915    Vistara   UK-838     Chennai          Night   one
# 295916  295916    Vistara   UK-838     Chennai          Night   one
# 295917  295917    Vistara   UK-838     Chennai          Night   one
#
#        arrival_time destination_city     class  duration  days_left  price
# 9997     Late_Night        Bangalore   Economy      2.92          1   7425
# ...

# %%
df['airline'].unique()
# Out:
# ['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo', 'Air_India']
# Categories (6, object): ['AirAsia', 'Air_India', 'GO_FIRST', 'Indigo', 'SpiceJet', 'Vistara']

# %%
df['airline'].value_counts()
df['airline'].value_counts().idxmax()
print(f'the maximum number of flights is {df["airline"].value_counts().max()} from {df['airline'].value_counts().idxmax()}')
# Out:
# the maximum number of flights is 127859 from Vistara

# %%
wmax_cost_of_GO_FIRST_flight = df[df['airline'] == 'GO_FIRST']['price'].max()
print(max_cost_of_GO_FIRST_flight)

min_cost_of_GO_FIRST_flight = df[df['airline'] == 'GO_FIRST']['price'].min()
print(min_cost_of_GO_FIRST_flight)
# Out:
# 32803
# 1105

# %%
min_cost_of_AirAsia_flight = df[df['airline'] == 'AirAsia']['price'].min()
print(min_cost_of_AirAsia_flight)

max_cost_of_AirAsia_flight = df[df['airline'] == 'AirAsia']['price'].max()
print(max_cost_of_AirAsia_flight)
# Out:
# 1105
# 31917

# %%
delhi_zero_stop_flights = df[(df['destination_city'] == 'Delhi') & (df['stops'] == 'zero')]
airline_counts = delhi_zero_stop_flights['airline'].value_counts()
max_flights_airline = airline_counts.idxmax()
max_flights_count = airline_counts.max()

print(f"The airline with the maximum number of zero-stop flights to Delhi is {max_flights_airline} with {max_flights_count} flights.")
# Out:
# The airline with the maximum number of zero-stop flights to Delhi is Vistara with 3472 flights.

# %%
average_price_by_airline = df.groupby('airline')['price'].mean().sort_values(ascending=False)
display(average_price_by_airline)
# Out:
# /tmp/ipython-input-248870357.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_price_by_airline = df.groupby('airline')['price'].mean().sort_values(ascending=False)
# airline
# Vistara      30396.536302
# Air_India    23507.019112
# SpiceJet      6179.278881
# GO_FIRST      5652.007595
# Indigo        5324.216303
# AirAsia       4091.072742
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
colors = np.random.rand(len(df))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(df['airline'], df['price'] , c= colors,alpha= 0.5, cmap= 'nipy_spectral')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.hist(df['price'], bins= 20,color='red', edgecolor='black')
plt.xlabel('price')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.title('Histogram of flight_price')
plt.show()

# %%
destination_counts = df['destination_city'].value_counts()

plt.figure(figsize=(10, 6))
destination_counts.plot(kind='bar', color='red')
plt.xlabel('Destination City')
plt.ylabel('Number of Flights')
plt.title('Number of Flights to Each Destination City')
plt.xticks(rotation=45, ha='right')
plt.grid()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Flight Price Distribution by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Flight Price Distribution by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('flights_data.csv')

plt.figure(figsize=(12, 8))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Flight Price Distribution by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['duration'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Flight Durations')
plt.xlabel('Duration (hours)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['duration'], df['price'], alpha=0.5)
plt.title('Flight Price vs. Duration')
plt.xlabel('Duration (hours)')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='stops', y='price', data=df)
plt.title('Flight Price Distribution by Number of Stops')
plt.xlabel('Number of Stops')
plt.ylabel('Price')
plt.show()

# %%
class_counts = df['class'].value_counts()

plt.figure(figsize=(8, 6))
class_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Distribution of Flight Classes')
plt.xlabel('Flight Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['days_left'], df['price'], alpha=0.5)
plt.title('Flight Price vs. Days Left Before Departure')
plt.xlabel('Days Left Before Departure')
plt.ylabel('Price')
plt.show()

# %%
max_price_by_class=df.groupby('class')['price'].max()
display(max_price_by_class)
# Out:
# class
# Business    123071
# Economy      42349
# Name: price, dtype: int64

# %%
avg_price_by_class=df.groupby('class')['price'].mean()
display(avg_price_by_class)
# Out:
# class
# Business    52540.081124
# Economy      6572.342383
# Name: price, dtype: float64

# %%
price_by_class = df.groupby('class')['price'].agg(['count', 'max', 'mean'])
display(price_by_class)
# Out:
#            count     max          mean
# class
# Business   93487  123071  52540.081124
# Economy   206666   42349   6572.342383

# %%
df['route'] = df['source_city'] + ' to ' + df['destination_city']
df['value'] = df['route'].value_counts()
amt=df[df['value'] * df['price']]
#all_routes=df['route'].value_counts()
display(amt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-317335174.py in <cell line: 0>()
#       1 df['route'] = df['source_city'] + ' to ' + df['destination_city']
#       2 df['value'] = df['route'].value_counts()
# ----> 3 amt=df[df['value'] * df['price']]
#       4 #all_routes=df['route'].value_counts()
#       5 display(amt)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...

# %%
income_by_route = df.groupby('route')['price'].sum()
display(income_by_route)
# Out:
# route
# Bangalore to Chennai      149493059
# Bangalore to Delhi        243801907
# Bangalore to Hyderabad    189506810
# Bangalore to Kolkata      235658614
# Bangalore to Mumbai       299261197
# Chennai to Bangalore      162856455
# Chennai to Delhi          185699575
# Chennai to Hyderabad      131771981
# Chennai to Kolkata        158304138
# Chennai to Mumbai         212587504
# Delhi to Bangalore        250537591
# Delhi to Chennai          208807321
# Delhi to Hyderabad        161815506
# Delhi to Kolkata          245439530
# Delhi to Mumbai           295931282
# Hyderabad to Bangalore    167660736
# Hyderabad to Chennai      139718382
# Hyderabad to Delhi        146677002
# Hyderabad to Kolkata      166320435
# Hyderabad to Mumbai       202093833
# Kolkata to Bangalore      223444998
# Kolkata to Chennai        157412382
# Kolkata to Delhi          204051257
# Kolkata to Hyderabad      169785590
# Kolkata to Mumbai         253178558
# Mumbai to Bangalore       298260354
# ...

# %%
df['route'].value_counts().idxmax()
# Out:
# 'Delhi to Mumbai'

# %%
average_price_by_route = df.groupby('route')['price'].max().idxmax()
display(average_price_by_route)
# Out:
# 'Kolkata to Delhi'

# %%
plt.figure(figsize=(12, 6))
top_routes.plot(kind='bar')
plt.title('Top 10 Flight Routes by Count')
plt.xlabel('Route')
plt.ylabel('Number of Flights')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
unique_routes = df.groupby('airline')['route'].nunique()
plt.figure(figsize=(8, 8))
plt.pie(unique_routes, labels=unique_routes.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Unique Routes per Airline')
plt.axis('equal')
plt.show()
