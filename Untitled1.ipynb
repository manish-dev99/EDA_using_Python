# %%
# Out:
#      CustomerID              Name  Age  Gender       Location    AccountType  \
# 0             1         Max Mckee   19    Male       New York       Checking
# 1             2    Jacob Williams   47    Male        Chicago  Fixed Deposit
# 2             3  William Peterson   52  Female        Atlanta       Checking
# 3             4      David Vargas   59    Male        Houston       Checking
# 4             5     Deanna Rogers   70    Male        Atlanta  Fixed Deposit
# ..          ...               ...  ...     ...            ...            ...
# 795         796     Frances Baker   32  Female         Dallas  Fixed Deposit
# 796         797         Sean Ball   34    Male        Seattle        Savings
# 797         798     Donna Marquez   46  Female         Boston       Business
# 798         799         Erin Rice   37    Male         Dallas        Savings
# 799         800    Charles Taylor   30  Female  San Francisco  Fixed Deposit
#
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(
      df,
      title="YData Profiling Report",
      explorative=True )
profile.to_file("your_report3.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-314455820.py in <cell line: 0>()
# ----> 1 from ydata_profiling import ProfileReport
#       2 profile = ProfileReport(
#       3       df,
#       4       title="YData Profiling Report",
#       5       explorative=True )
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install numpy==1.26.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 79.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport


# Load your dataset
# df = pd.read_csv("your_data.csv") # Commented out as df already exists

# Create the profile report with custom HTML settings
profile = ProfileReport(
    df, # Use the existing df
    title="YData Profiling Report",
    explorative=True,
    html={
        "minify_html": True,
        "use_local_assets": True,
        "inline": True,
        "navbar_show": True,
        "style": {
            "theme": "flatly",  # Options: 'flatly' (dark), 'united' (orange)
            # Replace None with the path to your uploaded image file
            "logo": "pngwing.com.png", # Example: "logo.png" or "/path/to/your/image.jpg"
            "primary_color": "#337ab7",
            "full_width": True
        }
    }
)

# Export to HTML
profile.to_file("your_report5.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-885322161.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3
#       4
#       5 # Load your dataset
#
# ModuleNotFoundError: No module named 'ydata_profiling'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 50.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.4 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=fb71a1ac5dfbc1ddddd13136550584a882d95091ed056dce7c496681b7797d8b
#   Stored in directory: /root/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport


# Load your dataset
df = pd.read_csv("Bank_Dataset.csv") # Commented out as df already exists

# Create the profile report with custom HTML settings
profile = ProfileReport(
    df, # Use the existing df
    title="YData Profiling Report",
    explorative=True,
    html={
        "minify_html": True,
        "use_local_assets": True,
        "inline": True,
        "navbar_show": True,
        "style": {
            "theme": "flatly",  # Options: 'flatly' (dark), 'united' (orange)
            # Replace None with the path to your uploaded image file
            "logo": "pngwing.com.png", # Example: "logo.png" or "/path/to/your/image.jpg"
            "primary_color": "#337ab7",
            "full_width": True
        }
    }
)

# Export to HTML
profile.to_file("your_report5.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 6])
ypoints = np.array([2, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 5, 6])
ypoints = np.array([4, 7, 9])

plt.plot(xpoints, ypoints)
plt.show()
