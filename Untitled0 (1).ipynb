# %%
import numpy as np
import pandas as pd

# %%
# df = pd.read_csv('Amazon_Dataset.csv')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %% [markdown]
# Add `%load_ext cudf.pandas` before importing pandas to speed up operations using GPU

# %%
# %load_ext cudf.pandas
import pandas as pd
import numpy as np

# Randomly generated dataset of parking violations-
# Define the number of rows
num_rows = 1000000

states = ["NY", "NJ", "CA", "TX"]
violations = ["Double Parking", "Expired Meter", "No Parking",
              "Fire Hydrant", "Bus Stop"]
vehicle_types = ["SUBN", "SDN"]

# Create a date range
start_date = "2022-01-01"
end_date = "2022-12-31"
dates = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate random data
data = {
    "Registration State": np.random.choice(states, size=num_rows),
    "Violation Description": np.random.choice(violations, size=num_rows),
    "Vehicle Body Type": np.random.choice(vehicle_types, size=num_rows),
    "Issue Date": np.random.choice(dates, size=num_rows),
    "Ticket Number": np.random.randint(1000000000, 9999999999, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Which parking violation is most commonly committed by vehicles from various U.S states?

(df[["Registration State", "Violation Description"]]  # get only these two columns
 .value_counts()  # get the count of offences per state and per type of offence
 .groupby("Registration State")  # group by state
 .head(1)  # get the first row in each group (the type of offence with the largest count)
 .sort_index()  # sort by state name
 .reset_index()
)

# %%
df.info()

# %%
df.describe()

# %%
df.shape

# %%
a = df.isnull().sum()
print(a)

# %%
df['Product Name'].unique()

# %%
df['Brand'].unique()

# %%
df['Seller Name'].unique()

# %%
a = df['Payment Method'] == 'Cash on Delivery'
b = df[a]
print(b)

# %%
a = df['Customer Location'] == 'Mumbai'
b = df[a]
print(b)

# %%
a = df['Brand'] == 'LG'
b = df[a]
print(b)

# %%
a = df['Payment Method'].value_counts()
print(a)

# %%
a = df['Brand'].value_counts()
print(a)

# %%
highest_price_per_brand = df.groupby('Brand')['Price'].max()
print(highest_price_per_brand)

# %%
import pandas as pd

df = pd.read_csv('Amazon_Dataset.csv')
laptop_df = df[df['Product Name'].str.contains('Laptop', case=False)]
display(laptop_df.value_counts())

# %%
Gaming_df = df[df['Product Name'].str.contains('Gaming', case=False)]
display(Gaming_df.value_counts())

# %%
gaming_df = df[df['Product Name'].str.contains('Gaming Console', case=False)]
a = gaming_df.groupby('Brand').size().reset_index(name='count')
print(a)

# %%
Washing_df = df[df['Product Name'].str.contains('Washing Machine', case=False)]
a = Washing_df.groupby('Brand').size().reset_index(name='count')
print(a)

# %%
a = df['Category'] == 'Grocery'
b = df[a]
print(b)

# %%
df = pd.read_csv('airlines_flights_data.csv')

# %%
df

# %%
df['airline'].unique()

# %%
a = df['airline'].value_counts().idxmax()
print(a)

# %%
highest_price_per_airline = df.groupby('airline')['price'].max()
print(highest_price_per_airline)

# %%
unique_price_per_airline = df.groupby('airline')['price'].unique()
print(unique_price_per_airline)

# %%
lowest_price_per_airline = df.groupby('airline')['price'].min()
print(lowest_price_per_airline)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Filter the DataFrame for flights with 1 or 2 days left before departure
last_minute_df = df[df['days_left'].isin([1, 2])]

#Analyze the price distribution for these last-minute tickets
print("Price statistics for tickets bought 1 or 2 days before departure:")
print(last_minute_df['price'].mean())

''' Visualize the price distribution using a histogram or box plot
plt.figure(figsize=(10, 6))
sns.histplot(last_minute_df['price'], bins=50, kde=True)
plt.title('Distribution of Prices for Last-Minute Tickets (1-2 Days Before Departure)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# You can also use a box plot to see the quartiles and outliers
plt.figure(figsize=(8, 6))
sns.boxplot(x='days_left', y='price', data=last_minute_df)
plt.title('Price Distribution by Days Left (1-2 Days Before Departure)')
plt.xlabel('Days Left Before Departure')
plt.ylabel('Price')
plt.show()'''

# %%
# Filter the DataFrame to show flights with 'Evening' departure time
evening_flights_df = df[df['departure_time'] == 'Evening']

# Display the filtered DataFrame
print(evening_flights_df)

# %%
# Filter the DataFrame for flights with 'one' stop
one_stop_flights = df[df['stops'] == 'one']

# Calculate the mean price for flights with 'one' stop
mean_price_one_stop = one_stop_flights['price'].mean()

print(f"Mean price for flights with one stop: {mean_price_one_stop}")

# %% [markdown]
# If you intended to convert the 'stops' column to numerical values and then calculate the mean number of stops across all flights, here is the code:

# %%
# Convert the 'stops' column to numerical values
# Assuming 'zero' corresponds to 0, 'one' to 1, 'two' to 2, etc.
stop_mapping = {'zero': 0, 'one': 1, 'two': 2, 'three': 3, 'four': 4} # Add other mappings if necessary
df['stops_numeric'] = df['stops'].map(stop_mapping)

# Calculate the mean of the numerical 'stops' column
mean_stops = df['stops_numeric'].mean()

print(f"The mean number of stops is: {mean_stops}")

# %%
a = df['destination_city'].value_counts().idxmax()
print(a)

# %%
lowest_price_per_airline = df.groupby('airline')['price'].min()
print(lowest_price_per_airline)

# %%
# Filter for flights from Delhi to Mumbai
delhi_mumbai_flights = df[(df['source_city'] == 'Delhi') & (df['destination_city'] == 'Mumbai')]

# Find the minimum price for these flights
cheapest_price_delhi_mumbai = delhi_mumbai_flights['price'].min()

print(f"The cheapest flight price from Delhi to Mumbai is: {cheapest_price_delhi_mumbai}")

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()

# Print the count of missing values for each column
print("Missing values per column:")
print(missing_values)
